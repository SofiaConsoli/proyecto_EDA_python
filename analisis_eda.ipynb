# %% [markdown]
# # Análisis Exploratorio de Datos - Campañas de Marketing Bancario
#
# El objetivo de este proyecto es analizar los datos de campañas de marketing de una entidad bancaria para identificar patrones y factores que influyen en la contratación de productos.

# %%
uhgjhg
